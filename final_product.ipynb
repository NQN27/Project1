# %%
from test_class import *
import folium
from Calculate_RealDistance import transform_matrix
from Code_interface import *
start,goal=Call_interface2()

answer = uniform_cost_search(encode(goal),encode(start))

answer_a = A_star_search(encode(goal), encode(start))

#answer_a1 = greedy_best_first_search(encode(goal), encode(start))

answer_a2 = A_star_search2(encode(goal), encode(start))

answer_a3 = A_star_plus_search(encode(goal), encode(start))

#answer_a4 = A_star_memory_plus_search(encode(goal), encode(start))
if answer == None: #if dont have any solutions
    print('no solution')
else:	
    solution = answer[0]
    path_u = answer[1]
    print('ucs minimum cost from {} to {} is {}'.format(start,goal,solution))
    print('path :')
    for i in path_u:
        print(i, end='->')
    print('UCS* nodes opened: ',expanded_nodes_U)
    print('total = ',sum(expanded_nodes_U.values()),' nodes')
    print('UCS* number of routes : ',len(expanded_routes_U))
print()
if answer_a == None: #if dont have any solutions
    print('no solution')

else:	
    solution = answer_a[0]
    path_a1 = answer_a[1]
    print('a* minimum cost from {} to {} is {}'.format(start,goal,solution))
    print('path :')
    for i in path_a1:
        print(i, end='->')        
    print('A* nodes opened: ',expanded_nodes_A1)
    print('total = ',sum(expanded_nodes_A1.values()),' nodes')
    print('A* number of routes : ',len(expanded_routes_A1))
print()

if answer_a2 == None: #if dont have any solutions
    print('no solution')

else:	
    solution = answer_a2[0]
    path_a2 = answer_a2[1]
    print('a* 2 minimum cost from {} to {} is {}'.format(start,goal,solution))
    print('path :')
    for i in path_a2:
        print(i, end='->')        
    print('A* 2 nodes opened: ',expanded_nodes_A2)
    print('total = ',sum(expanded_nodes_A2.values()),' nodes')
    print('A* 2 number of routes : ',len(expanded_routes_A2))
print()
if answer_a3 == None: #if dont have any solutions
    print('no solution')

else:	
    solution = answer_a3[0]
    path_a3 = answer_a3[1]
    print('a* plus minimum cost from {} to {} is {}'.format(start,goal,solution))
    print('path :')
    for i in path_a3:
        print(i, end='->')        
    print('A* plus nodes opened: ',expanded_nodes_A3)
    print('total = ',sum(expanded_nodes_A3.values()),' nodes')
    print('A* plus number of routes : ',len(expanded_routes_A3))
print()
# Out:
# ucs minimum cost from HaNoi to HoChiMinhCity is 1687.984
# path :
# HaNoi->PhuLy->NinhBinh->ThanhHoa->Vinh->HaTinh->DongHoi(QB)->DongHa->Hue->TamKy->KonTum->Pleiku->BuonMaThuot->GiaNghia(DakNong)->DongXoai(Binh Phuoc)->ThuDauMot->HoChiMinhCity->UCS* nodes opened:  {'BacGiang': 5, 'BacNinh': 3, 'HoaBinh': 5, 'HungYen': 4, 'PhuLy': 5, 'ThaiNguyen': 4, 'VietTri': 5, 'VinhYen': 2, 'HaiDuong': 4, 'HaNoi': 7, 'TuyenQuang': 5, 'HaLong': 2, 'LangSon': 4, 'ThaiBinh': 4, 'NamDinh': 2, 'NinhBinh': 3, 'SonLa': 4, 'ThanhHoa': 2, 'BacKan': 3, 'YenBai': 4, 'HaiPhong': 2, 'HaGiang': 3, 'CaoBang': 2, 'LaoCai': 3, 'Vinh': 1, 'DienBienPhu': 1, 'HaTinh': 1, 'LaiChau': 1, 'DongHoi(QB)': 1, 'DongHa': 1, 'Hue': 2, 'DaNang': 1, 'TamKy': 3, 'KonTum': 2, 'QuangNgai': 2, 'QuiNhon': 2, 'Pleiku': 3, 'TuyHoa': 3, 'BuonMaThuot': 4, 'NhaTrang': 2, 'PhanRang-ThapCham': 2, 'DaLat': 4, 'GiaNghia(DakNong)': 2, 'PhanThiet': 2, 'DongXoai(Binh Phuoc)': 5, 'BienHoa': 1, 'TayNinh': 1, 'ThuDauMot': 2, 'HoChiMinhCity': 2, 'BaRia-VungTau': 0}
# total =  138  nodes
# UCS* number of routes :  188
#
# a* minimum cost from HaNoi to HoChiMinhCity is 1687.984
# path :
# HaNoi->PhuLy->NinhBinh->ThanhHoa->Vinh->HaTinh->DongHoi(QB)->DongHa->Hue->TamKy->KonTum->Pleiku->BuonMaThuot->GiaNghia(DakNong)->DongXoai(Binh Phuoc)->ThuDauMot->HoChiMinhCity->A* nodes opened:  {'BacGiang': 5, 'BacNinh': 3, 'HoaBinh': 5, 'HungYen': 4, 'PhuLy': 5, 'ThaiNguyen': 4, 'VietTri': 5, 'VinhYen': 2, 'HaNoi': 7, 'NamDinh': 2, 'NinhBinh': 3, 'ThaiBinh': 4, 'ThanhHoa': 2, 'HaiDuong': 4, 'Vinh': 1, 'HaiPhong': 2, 'HaTinh': 1, 'SonLa': 3, 'DongHoi(QB)': 1, 'TuyenQuang': 5, 'HaLong': 2, 'LangSon': 4, 'DongHa': 1, 'YenBai': 4, 'Hue': 2, 'BacKan': 3, 'DaNang': 1, 'TamKy': 3, 'HaGiang': 3, 'CaoBang': 2, 'LaoCai': 2, 'KonTum': 2, 'QuangNgai': 2, 'QuiNhon': 2, 'DienBienPhu': 0, 'Pleiku': 3, 'TuyHoa': 3, 'BuonMaThuot': 3, 'NhaTrang': 2, 'DaLat': 3, 'GiaNghia(DakNong)': 1, 'DongXoai(Binh Phuoc)': 1, 'PhanRang-ThapCham': 0, 'LaiChau': 0, 'BienHoa': 1, 'PhanThiet': 1, 'TayNinh': 1, 'ThuDauMot': 0, 'HoChiMinhCity': 0}
# total =  120  nodes
# A* number of routes :  169
#
# a* 2 minimum cost from HaNoi to HoChiMinhCity is 1687.984
# path :
# HaNoi->PhuLy->NinhBinh->ThanhHoa->Vinh->HaTinh->DongHoi(QB)->DongHa->Hue->TamKy->KonTum->Pleiku->BuonMaThuot->GiaNghia(DakNong)->DongXoai(Binh Phuoc)->ThuDauMot->HoChiMinhCity->A* 2 nodes opened:  {'BacGiang': 0, 'BacNinh': 0, 'HoaBinh': 3, 'HungYen': 1, 'PhuLy': 1, 'ThaiNguyen': 0, 'VietTri': 0, 'VinhYen': 0, 'HaNoi': 0, 'NamDinh': 1, 'NinhBinh': 1, 'ThaiBinh': 0, 'ThanhHoa': 1, 'Vinh': 1, 'HaTinh': 1, 'DongHoi(QB)': 1, 'DongHa': 1, 'Hue': 1, 'DaNang': 1, 'TamKy': 1, 'KonTum': 1, 'QuangNgai': 1, 'Pleiku': 1, 'BuonMaThuot': 1, 'QuiNhon': 0, 'TuyHoa': 1, 'DaLat': 2, 'GiaNghia(DakNong)': 1, 'NhaTrang': 0, 'DongXoai(Binh Phuoc)': 1, 'BienHoa': 1, 'PhanThiet': 0, 'TayNinh': 1, 'ThuDauMot': 0, 'HoChiMinhCity': 0}
# total =  26  nodes
# A* 2 number of routes :  61
#
# a* plus minimum cost from HaNoi to HoChiMinhCity is 1687.984
# path :
# HaNoi->PhuLy->NinhBinh->ThanhHoa->Vinh->HaTinh->DongHoi(QB)->DongHa->Hue->TamKy->KonTum->Pleiku->BuonMaThuot->GiaNghia(DakNong)->DongXoai(Binh Phuoc)->ThuDauMot->HoChiMinhCity->A* plus nodes opened:  {'BacGiang': 5, 'BacNinh': 3, 'HoaBinh': 5, 'HungYen': 4, 'PhuLy': 5, 'ThaiNguyen': 4, 'VietTri': 5, 'VinhYen': 2, 'HaNoi': 7, 'NamDinh': 2, 'NinhBinh': 3, 'ThaiBinh': 4, 'ThanhHoa': 2, 'HaiDuong': 4, 'Vinh': 1, 'HaTinh': 1, 'DongHoi(QB)': 1, 'DongHa': 1, 'Hue': 2, 'DaNang': 1, 'TamKy': 3, 'KonTum': 2, 'QuangNgai': 2, 'QuiNhon': 2, 'HaiPhong': 2, 'SonLa': 3, 'TuyenQuang': 5, 'HaLong': 2, 'LangSon': 4, 'YenBai': 4, 'Pleiku': 3, 'TuyHoa': 3, 'BacKan': 3, 'BuonMaThuot': 4, 'NhaTrang': 2, 'HaGiang': 3, 'CaoBang': 2, 'LaoCai': 2, 'PhanRang-ThapCham': 2, 'DaLat': 4, 'GiaNghia(DakNong)': 2, 'DienBienPhu': 0, 'PhanThiet': 2, 'DongXoai(Binh Phuoc)': 4, 'BienHoa': 1, 'TayNinh': 1, 'ThuDauMot': 1, 'LaiChau': 0, 'HoChiMinhCity': 1, 'BaRia-VungTau': 0}
# total =  131  nodes
# A* plus number of routes :  181

# %%
dl = pd.read_excel(r"Data\Location.xlsx")
loc_matrix = np.array(dl)

START = ["START", float(transform_matrix(start)[0]), float(transform_matrix(start)[1])]
END = ['ENDS', float(transform_matrix(goal)[0]), float(transform_matrix(goal)[1])]

# %%
m = folium.Map(
location=[16, 108],
tiles='cartodbpositron',
zoom_start=7,
)

from folium.plugins import Geocoder
Geocoder().add_to(m)

# %%
def draw_line(city, l, loc_matrix, col):
    path = city.path
    newpath = []
    for name in path:
        for city in loc_matrix:
            if city[0] == name:
                coor = city[1].split(',')
                latitude = float(coor[0])
                longitude = float(coor[1].strip())
                newpath.append([name, latitude, longitude])
    lines = []
    for i in newpath:
        lines.append(tuple(i[1:]))
    folium.PolyLine(lines, color = col, weight = 2).add_to(l)

# %%
optimal_layer = folium.FeatureGroup(name = "optimal layer by ucs/a*")
ucs_layer = folium.FeatureGroup(name = "ucs layer")
a_star_layer1 = folium.FeatureGroup(name = "a* layer with coef = 1")
a_star_layer2 = folium.FeatureGroup(name = "a* layer with coef = 2")

optimal_path = path_u

newpath = [START]
for name in optimal_path:
    for city in loc_matrix:
        if city[0] == name:
            coor = city[1].split(',')
            latitude = float(coor[0])
            longitude = float(coor[1].strip())
            newpath.append([name, latitude, longitude])

newpath.append(END)

for city in newpath:
    if city[0] == 'START':
        pop = 'your starting point'
        col = 'lightgreen'
    elif city[0] == 'ENDS':
        pop = 'your ending point'
        col = 'red'
    else:
        pop = 'in a route'
        col = 'orange'
    folium.Marker(
    location = city[1:],
    popup = pop,
    tooltip = city[0],
    icon = folium.Icon(color = col)
    ).add_to(optimal_layer)

for city in loc_matrix:
    if city[0] not in optimal_path:
        coor = city[1].split(',')
        latitude = float(coor[0])
        longitude = float(coor[1].strip())
        folium.Marker(
            location = [latitude, longitude],
            popup = 'not in any route',
            tooltip = city[0]
        ).add_to(optimal_layer)
    if city[0] in expanded_nodes_U:
        coor = city[1].split(',')
        latitude = float(coor[0])
        longitude = float(coor[1].strip())
        if expanded_nodes_U[city[0]] <= 4:
            col = 'lightgreen'
        elif expanded_nodes_U[city[0]] > 4 and expanded_nodes_U[city[0]] <= 6:
            col = 'orange'
        else:
            col = 'red'
        folium.Marker(
            location = [latitude, longitude],
            popup = 'appear {} times'.format(expanded_nodes_U[city[0]]),
            tooltip = city[0],
            icon = folium.Icon(color = col)
        ).add_to(ucs_layer)
    else: 
        coor = city[1].split(',')
        latitude = float(coor[0])
        longitude = float(coor[1].strip())
        folium.Marker(
            location = [latitude, longitude],
            popup = "haven't expanded",
            tooltip = city[0]
        ).add_to(ucs_layer)

    if city[0] in expanded_nodes_A1:
        coor = city[1].split(',')
        latitude = float(coor[0])
        longitude = float(coor[1].strip())
        if expanded_nodes_A1[city[0]] <= 4:
            col = 'lightgreen'
        elif expanded_nodes_A1[city[0]] > 4 and expanded_nodes_A1[city[0]] <= 6:
            col = 'orange'
        else:
            col = 'red'
        folium.Marker(
            location = [latitude, longitude],
            popup = 'appear {} times'.format(expanded_nodes_A1[city[0]]),
            tooltip = city[0],
            icon = folium.Icon(color = col)
        ).add_to(a_star_layer1)
    else: 
        coor = city[1].split(',')
        latitude = float(coor[0])
        longitude = float(coor[1].strip())
        folium.Marker(
            location = [latitude, longitude],
            popup = "haven't expanded",
            tooltip = city[0]
        ).add_to(a_star_layer1)
    
    if city[0] in expanded_nodes_A2:
        coor = city[1].split(',')
        latitude = float(coor[0])
        longitude = float(coor[1].strip())
        if expanded_nodes_A2[city[0]] <= 4:
            col = 'lightgreen'
        elif expanded_nodes_A2[city[0]] > 4 and expanded_nodes_A2[city[0]] <= 6:
            col = 'orange'
        else:
            col = 'red'
        folium.Marker(
            location = [latitude, longitude],
            popup = 'appear {} times'.format(expanded_nodes_A2[city[0]]),
            tooltip = city[0],
            icon = folium.Icon(color = col)
        ).add_to(a_star_layer2)
    else: 
        coor = city[1].split(',')
        latitude = float(coor[0])
        longitude = float(coor[1].strip())
        folium.Marker(
            location = [latitude, longitude],
            popup = "haven't expanded",
            tooltip = city[0]
        ).add_to(a_star_layer2)
    
lines = []
for i in newpath:
    lines.append(tuple(i[1:]))
folium.PolyLine(lines, color = 'red', weight = 5).add_to(optimal_layer)

for city in expanded_routes_U:
    draw_line(city, ucs_layer, loc_matrix, 'pink')
    
for city in expanded_routes_A1:
    draw_line(city, a_star_layer1, loc_matrix, 'purple')
    
for city in expanded_routes_A2:
    draw_line(city, a_star_layer2, loc_matrix, 'blue')

optimal_layer.add_to(m)
ucs_layer.add_to(m)
a_star_layer1.add_to(m)
a_star_layer2.add_to(m)

folium.LayerControl().add_to(m)

m
show_map(m)
